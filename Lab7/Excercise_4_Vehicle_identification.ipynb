# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushila-Phogat/CE888/blob/master/Lab7/Excercise_4_Vehicle_identification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_USERNAME'] = "sushilakumari" # username from the json file
os.environ['KAGGLE_KEY'] = "a30f4b655bb5bf8eb150ba025d090bac" # key from the json file
# !kaggle competitions download -c image-classification2 # api copied from kaggle
# Out:
# ...
#  96% 219M/229M [00:04<00:00, 64.2MB/s]
# 100% 229M/229M [00:04<00:00, 55.8MB/s]
# ...
#  95% 281M/297M [00:05<00:00, 58.1MB/s]
# 100% 297M/297M [00:05<00:00, 58.2MB/s]
# ...
#   0% 0.00/17.3k [00:00<?, ?B/s]
# 100% 17.3k/17.3k [00:00<00:00, 15.9MB/s]

# %%
# Upload data
from zipfile import ZipFile

file_name = "/content/cltask.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
print(os.listdir('/content/cltask/test'))
# Out:
# ['1697246533.jpg', '102354905.jpg', '2441496.jpg', '1550979830.jpg', '43825261.jpg', '147990098.jpg', '1079502557.jpg', '614207102.jpg', '1053074867.jpg', '263160818.jpg', '254925607.jpg', '2141292530.jpg', '1224153972.jpg', '968362219.jpg', '1695686397.jpg', '594118006.jpg', '816551281.jpg', '375476009.jpg', '317248725.jpg', '738628670.jpg', '782643461.jpg', '457085839.jpg', '1476083143.jpg', '1094656381.jpg', '66351434.jpg', '2035653887.jpg', '737605256.jpg', '111730302.jpg', '1542414088.jpg', '1921651015.jpg', '1602643125.jpg', '280433371.jpg', '2143306575.jpg', '514858042.jpg', '1651556225.jpg', '1048254415.jpg', '949316883.jpg', '1160808113.jpg', '1453702897.jpg', '1729656771.jpg', '896593704.jpg', '2128649873.jpg', '1546057066.jpg', '1172636252.jpg', '1088424500.jpg', '1709483826.jpg', '1270789304.jpg', '276257262.jpg', '1828515589.jpg', '1266531286.jpg', '1206038283.jpg', '128417703.jpg', '743978624.jpg', '1019764456.jpg', '304006838.jpg', '2106959161.jpg', '701611339.jpg', '1
# ...

# %%
data_dir_list = os.listdir('/content/cltask/train')
#print(data_dir_list)

path, dirs, files = next(os.walk("/content/cltask/train/bicycle"))
file_count = len(files)
print(file_count)
# Out:
# 269

# %%
original_dataset_dir = '/content/cltask/train'
base_dir = '/content/vehicles'
os.mkdir(base_dir)

# %%
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)


test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

train_motorbike_dir = os.path.join(train_dir, 'motorbike')
os.mkdir(train_motorbike_dir)

train_bicycle_dir = os.path.join(train_dir, 'bicycle')
os.mkdir(train_bicycle_dir)

train_car_dir = os.path.join(train_dir, 'car')
os.mkdir(train_car_dir)

validation_motorbike_dir = os.path.join(validation_dir, 'motorbike')
os.mkdir(validation_motorbike_dir)

validation_bicycle_dir = os.path.join(validation_dir, 'bicycle')
os.mkdir(validation_bicycle_dir)

validation_car_dir = os.path.join(validation_dir, 'car')
os.mkdir(validation_car_dir)

test_motorbike_dir = os.path.join(test_dir, 'motorbike')
os.mkdir(test_motorbike_dir)

test_bicycle_dir = os.path.join(test_dir, 'bicycle')
os.mkdir(test_bicycle_dir)

test_car_dir = os.path.join(test_dir, 'car')
os.mkdir(test_car_dir)
